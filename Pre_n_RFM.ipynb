# %% [markdown]
# <a href="https://colab.research.google.com/github/nilamaula26/Praktikum-Kuliah/blob/main/Pre_n_RFM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import datetime as dt
from sklearn.preprocessing import StandardScaler
# Daftar file Excel yang akan digabungkan
file_paths = ['1.xlsx','2.xlsx','3.xlsx','4.xlsx','5.xlsx','6.xlsx','7.xlsx',
              '8.xlsx','9.xlsx','10.xlsx','11.xlsx','12.xlsx','13.xlsx','14.xlsx',
              '15.xlsx','16.xlsx','17.xlsx','18.xlsx','19.xlsx','20.xlsx','21.xlsx',
              '22.xlsx','23.xlsx','24.xlsx','25.xlsx','26.xlsx','27.xlsx','28.xlsx',
              '29.xlsx','30.xlsx','31.xlsx','32.xlsx','33.xlsx','34.xlsx','35.xlsx',
              '36.xlsx','37.xlsx','38.xlsx','39.xlsx','40.xlsx','41.xlsx','42.xlsx',
              '43.xlsx']

# Inisialisasi list untuk menyimpan DataFrame dari setiap file Excel
dfs = []

# Baca setiap file Excel dan tambahkan DataFrame ke dalam list
for file_path in file_paths:
    df = pd.read_excel(file_path)
    dfs.append(df)

# Gabungkan DataFrame menggunakan pd.concat()
combined_df = pd.concat(dfs, ignore_index=True)

# Simpan DataFrame hasil penggabungan ke dalam file Excel
combined_df.to_excel('Raw Data.xlsx', index=False)

# %%
combined_df.head()
# Out:
#       No. Pesanan Status Pesanan Status Pembatalan/ Pengembalian  \
# 0  2010029FXA90EA        Selesai                             NaN
# 1  201002A7W4B5FC        Selesai                             NaN
# 2  201002A7W4B5FC        Selesai                             NaN
# 3  201005H5PFSP1P        Selesai                             NaN
# 4  201006KTW2N0GG        Selesai                             NaN
#
#            No. Resi Opsi Pengiriman Antar ke counter/ pick-up  \
# 0      JP8495227750     J&T Express          Antar ke Counter
# 1      JP3885388617     J&T Express          Antar ke Counter
# 2      JP3885388617     J&T Express          Antar ke Counter
# 3  8825112084827301     JNE Reguler                    Pickup
# 4     SHP2648604960    Ninja Xpress                    Pickup
#
#   Pesanan Harus Dikirimkan Sebelum (Menghindari keterlambatan)  \
# 0                                   2020-10-13 15:26
# 1                                   2020-10-06 07:07
# ...

# %%
# Menggunakan len() untuk menghitung jumlah data
jumlah_data = len(combined_df)

print("Jumlah data:", jumlah_data)
# Out:
# Jumlah data: 13227

# %%
# Baca file Excel ke dalam DataFrame
df = pd.read_excel('Raw Data.xlsx')

# Identifikasi baris yang memiliki nilai 'Permintaan Disetujui' di kolom 'Status Pembatalan/ Pengembalian'
rows_to_drop = df[df['Status Pembatalan/ Pengembalian'] == 'Permintaan Disetujui'].index

# Hapus nilai yang sesuai
df.drop(rows_to_drop, inplace=True)

# %%
# Tentukan kolom yang ingin dihapus
kolom_yang_dihapus = [kolom for kolom in df.columns if kolom not in ['Waktu Pesanan Dibuat', 'Username (Pembeli)', 'Total Harga Produk']]

# Buat DataFrame baru dengan hanya menyertakan kolom yang diinginkan
df_baru = df.drop(columns=kolom_yang_dihapus)

# %%
df_baru.head()
# Out:
#   Waktu Pesanan Dibuat  Total Harga Produk Username (Pembeli)
# 0     2022-12-18 07:05           2800000.0            nurilbm
# 1     2023-02-13 15:10           1800000.0        damiatun015
# 2     2023-10-18 15:55           1772500.0  bareeqbembyatmaja
# 3     2022-10-20 14:29           1540000.0       sulistyantik
# 4     2024-04-22 06:06           1440000.0         laelatur92

# %%
# Mengubah nama atribut
df_baru = df_baru.rename(columns={'Waktu Pesanan Dibuat': 'date','Total Harga Produk':'paid_price','Username (Pembeli)':'username'})

# %%
df_baru.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13159 entries, 0 to 13226
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        13159 non-null  object
#  1   paid_price  13159 non-null  float64
#  2   username    13093 non-null  object
# dtypes: float64(1), object(2)
# memory usage: 927.3+ KB

# %%
mv=df_baru.isnull().sum()
print(mv)
# Out:
# date           0
# paid_price     0
# username      66
# dtype: int64

# %%
# Mengonversi kolom 'Waktu Pesanan Dibuat' menjadi tipe data datetime
df_baru['date'] = pd.to_datetime(df_baru['date'])
df_baru['paid_price']=df_baru['paid_price'].astype(int)

# Mengambil hanya bagian tanggal (hari)
df_baru['date'] = df_baru['date'].dt.date
df_baru['date'] = pd.to_datetime(df_baru['date'])

# %%
# Menghapus Missing Values
cleaned_data = df_baru.dropna()

# %%
mv=cleaned_data.isnull().sum()
print(mv)
# Out:
# date          0
# paid_price    0
# username      0
# dtype: int64

# %%
# Menyimpan data ke dalam bentuk excel
df_baru.to_excel("selected.xlsx",index=False)

# %%
# Menggunakan len() untuk menghitung jumlah data
jumlah_data = len(cleaned_data)

print("Jumlah data:", jumlah_data)
# Out:
# Jumlah data: 13093

# %%
# Mengubah dataset ke dalam bentuk RFM
present = dt.datetime(2024,5,1)
rfm = cleaned_data.groupby('username').agg({
    'date': lambda date: (present - dt.datetime.combine(date.max(), dt.datetime.min.time())).days,
    'username': lambda num: len(num),
    'paid_price': lambda price: price.sum()
})

# %%
# Mengubah nama atribut dataset
rfm.columns=['recency','frequency', 'monetary']

# %%
rfm.head()
# Out:
#                            recency  frequency  monetary
# username
# .........mmm..........mm.      478          1    120000
# ......090909                   198          1     60000
# ...080692                      902          1     69900
# .dafiagus01                    449          1     90000
# .syahrina842                   691          6   1305000

# %%
rfm.describe()
# Out:
#            recency    frequency      monetary
# count  9010.000000  9010.000000  9.010000e+03
# mean    403.223196     1.453163  1.530155e+05
# std     235.846518     1.158383  2.088286e+05
# min       1.000000     1.000000  2.000000e+04
# 25%     208.000000     1.000000  8.000000e+04
# 50%     393.000000     1.000000  1.090000e+05
# 75%     573.000000     2.000000  1.450000e+05
# max    1307.000000    29.000000  4.390000e+06

# %%
# Standarisasi fitur
scaler = StandardScaler()
rfm_scaled = scaler.fit_transform(rfm)

# %%
print(rfm_scaled)
# Out:
# [[ 0.31707466 -0.39122496 -0.15810755]
#  [-0.87020401 -0.39122496 -0.44544051]
#  [ 2.11495378 -0.39122496 -0.39803057]
#  ...
#  [-0.71331362 -0.39122496 -0.49332933]
#  [-0.24264243 -0.39122496 -0.15810755]
#  [-1.67585739 -0.39122496 -0.27782962]]

# %%
rfm_scaled = pd.DataFrame(rfm_scaled)
rfm_scaled.to_excel('rfm_scaled.xlsx', index=False)
