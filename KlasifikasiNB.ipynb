# %% [markdown]
# <a href="https://colab.research.google.com/github/nilamaula26/Praktikum-Kuliah/blob/main/KlasifikasiNB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Nama : Nihlatil Maula
# #Kelas : Teknologi Informasi '20A
# #NIM : 101200015

# %% [markdown]
# Import package that will use.

# %%
import pandas as pd
import numpy as np
import matplotlib.colors
from sklearn import datasets
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

# %% [markdown]
# Load the dataset and show the data.

# %%
df = pd.read_csv('/content/Social_Network_Ads.csv')
df.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %% [markdown]
# Divide the data into 2, x and y, where x is 'Age ' and 'EstimatedSalary', and y is 'Purchased'.

# %%
x= df.iloc[:,[2,3]].values
y= df.iloc[:,-1]

# %% [markdown]
# Print the x and y data.

# %%
print(x)
# Out:
# [[    19  19000]
#  [    35  20000]
#  [    26  43000]
#  [    27  57000]
#  [    19  76000]
#  [    27  58000]
#  [    27  84000]
#  [    32 150000]
#  [    25  33000]
#  [    35  65000]
#  [    26  80000]
#  [    26  52000]
#  [    20  86000]
#  [    32  18000]
#  [    18  82000]
#  [    29  80000]
#  [    47  25000]
#  [    45  26000]
#  [    46  28000]
#  [    48  29000]
#  [    45  22000]
#  [    47  49000]
#  [    48  41000]
#  [    45  22000]
#  [    46  23000]
#  [    47  20000]
#  [    49  28000]
#  [    47  30000]
#  [    29  43000]
#  [    31  18000]
#  [    31  74000]
#  [    27 137000]
#  [    21  16000]
#  [    28  44000]
#  [    27  90000]
#  [    35  27000]
#  [    33  28000]
#  [    30  49000]
#  [    26  72000]
#  [    27  31000]
#  [    27  17000]
#  [    33  51000]
#  [    35 108000]
#  [    30  15000]
#  [    28  84000]
#  [    23  20000]
#  [    25  79000]
#  [    27  54000]
#  [    30 135000]
#  [    31  89000]
#  [    24  32000]
#  [    18  44000]
# ...

# %%
print(y)
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 395    1
# 396    1
# 397    1
# 398    0
# 399    1
# Name: Purchased, Length: 400, dtype: int64

# %% [markdown]
# Split the data into training set and test set with ratio 3/4 : 1/4.

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.25, random_state=0)

# %% [markdown]
# Preprocessing the data with StandardScaler for standardize the data.

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %% [markdown]
# Print the x_train and x_test data.

# %%
print(x_train)
# Out:
# [[ 0.58164944 -0.88670699]
#  [-0.60673761  1.46173768]
#  [-0.01254409 -0.5677824 ]
#  [-0.60673761  1.89663484]
#  [ 1.37390747 -1.40858358]
#  [ 1.47293972  0.99784738]
#  [ 0.08648817 -0.79972756]
#  [-0.01254409 -0.24885782]
#  [-0.21060859 -0.5677824 ]
#  [-0.21060859 -0.19087153]
#  [-0.30964085 -1.29261101]
#  [-0.30964085 -0.5677824 ]
#  [ 0.38358493  0.09905991]
#  [ 0.8787462  -0.59677555]
#  [ 2.06713324 -1.17663843]
#  [ 1.07681071 -0.13288524]
#  [ 0.68068169  1.78066227]
#  [-0.70576986  0.56295021]
#  [ 0.77971394  0.35999821]
#  [ 0.8787462  -0.53878926]
#  [-1.20093113 -1.58254245]
#  [ 2.1661655   0.93986109]
#  [-0.01254409  1.22979253]
#  [ 0.18552042  1.08482681]
#  [ 0.38358493 -0.48080297]
#  [-0.30964085 -0.30684411]
#  [ 0.97777845 -0.8287207 ]
#  [ 0.97777845  1.8676417 ]
#  [-0.01254409  1.25878567]
#  [-0.90383437  2.27354572]
#  [-1.20093113 -1.58254245]
#  [ 2.1661655  -0.79972756]
#  [-1.39899564 -1.46656987]
#  [ 0.38358493  2.30253886]
# ...

# %%
print(x_test)
# Out:
# [[-0.80480212  0.50496393]
#  [-0.01254409 -0.5677824 ]
#  [-0.30964085  0.1570462 ]
#  [-0.80480212  0.27301877]
#  [-0.30964085 -0.5677824 ]
#  [-1.10189888 -1.43757673]
#  [-0.70576986 -1.58254245]
#  [-0.21060859  2.15757314]
#  [-1.99318916 -0.04590581]
#  [ 0.8787462  -0.77073441]
#  [-0.80480212 -0.59677555]
#  [-1.00286662 -0.42281668]
#  [-0.11157634 -0.42281668]
#  [ 0.08648817  0.21503249]
#  [-1.79512465  0.47597078]
#  [-0.60673761  1.37475825]
#  [-0.11157634  0.21503249]
#  [-1.89415691  0.44697764]
#  [ 1.67100423  1.75166912]
#  [-0.30964085 -1.37959044]
#  [-0.30964085 -0.65476184]
#  [ 0.8787462   2.15757314]
#  [ 0.28455268 -0.53878926]
#  [ 0.8787462   1.02684052]
#  [-1.49802789 -1.20563157]
#  [ 1.07681071  2.07059371]
#  [-1.00286662  0.50496393]
#  [-0.90383437  0.30201192]
#  [-0.11157634 -0.21986468]
#  [-0.60673761  0.47597078]
#  [-1.6960924   0.53395707]
#  [-0.11157634  0.27301877]
#  [ 1.86906873 -0.27785096]
#  [-0.11157634 -0.48080297]
# ...

# %% [markdown]
# Predict the data with Naive Bayes.

# %%
model = GaussianNB()

model.fit(x_train, y_train);

# %%
y_pred = model.predict(x_test)

# %% [markdown]
# Calculate the confusion matrix and print it for evaluating.

# %%
print("Confussion matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Confussion matrix:
#  [[65  3]
#  [ 7 25]]

# %% [markdown]
# Visualize the data.

# %%
x_set, y_set = x_train, y_train
x1, x2 = np.meshgrid(np.arange(start=x_set[:,0].min()-1, stop=x_set[:,0].max()+1, step=0.01),
                     np.arange(start=x_set[:,1].min()-1, stop=x_set[:,0].max()+1, step=0.01))

plt.contour(x1,x2, model.predict(np.array([x1.ravel(), x2.ravel()]).T).reshape(x1.shape),
            alpha = 0.75, cmap = matplotlib.colors.ListedColormap(('red', 'green')))
plt.xlim(x1.min(), x1.max())
plt.ylim(x2.min(), x2.max())
for i, j in enumerate(np.unique(y_set)):
  plt.scatter(x_set[y_set == j,0], x_set[y_set==j,1],
              color = matplotlib.colors.ListedColormap(('red', 'green')) (i), label=j)
  plt.title('Klasifikasi Data dengan Naive Bayes (Data Training)')
  plt.xlabel('Umur')
  plt.ylabel('Estimasi Gaji')
  plt.legend
  plt.show()
